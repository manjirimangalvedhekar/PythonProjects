# %%
import time

# %%
print("Welcome to Quick Health Pro-Max Interactive Symptom Checker")
print("Hello there! Let's check how you're doing today!")
#1.USER PROFILE"
points = 0
user_name = input("Enter your name: ").strip()
user_age = int(input("Enter your age: ")) 
user_gender = input("Enter your Gender (male, female, other) :").strip()
user_city = input("Enter your city:").strip()
time.sleep(2)
#"2.HEALTH INPUTS"
main_symptoms = input("Enter your symptom choose from: fever, cough, fatigue, headache, chestpain, breathlessness").strip()
body_temperature = float(input("Enter you're temperature in Farenheit"))
num_sick_days = int(input("Since how many days you are sick?: "))
smoking_habit = input("Do you smoke yes/no: ")
sleep_hours = int(input("How many hours do you sleep?: "))
mood_right_now = input("Choose from: calm, anxious, sad, irritable")
pre_existing_cond = input("Enter either yes/no")
time.sleep(2)
print(".RISK SCORING LOGIC")
if body_temperature >= 102 or num_sick_days > 3:
    points +=3
elif user_age >= 60 and main_symptoms.upper()== "FEVER":
    points +=2
elif  main_symptoms.upper() =="COUGH" and num_sick_days >= 5:
    points +=2
elif main_symptoms.upper() == "FATIGUE" and user_age > 30:
    points +=2
elif main_symptoms.upper() == "HEADACHE" and body_temperature > 100:
    points +=2
elif  main_symptoms.upper() == "CHESTPAIN":
    points +=3
elif main_symptoms.upper() == "BEEATHLESSNESS":
    points +=4


if smoking_habit.upper() == "YES":
    points +=2
if mood_right_now.upper() in ("ANXIOUS", "SAD" , "IRRITABLE"):
    points +=1
if pre_existing_cond.upper() == "YES":
    points +=2
else:
    print("You are good to go")
time.sleep(3)
print("HEALTH RISK RESULT")
if points > 0 and points <= 3:
    print("You are at LOW RISK")
elif points >= 4 and points <=6:
    print("You are at MODERATE RISK")
else:
    print("You are at HIGH RISK")
time.sleep(3)
print("5.PERSONAL ADVICE")
if user_gender.upper() == "FEMALE" and user_age >= 45:
    print("You require health screening")
if  user_gender.upper() == "MALE" and smoking_habit.upper() =="YES":
    print("You need to quit SMOKING")
if sleep_hours < 6:
    print("Take adequte sleep, preferabaly 7 to 8 hours")
if mood_right_now.upper() == "ANXIOUS":
    print("Try relaxing mood")
if pre_existing_cond.upper()== "YES":
    print("Take medical assistance")
print("Take a rouitne checkup to avoid further issues")
time.sleep(3)
print("6.MENTAL HEALTH TIP")
if mood_right_now.upper() == "CALM":
    print("Encourage positivity")
elif mood_right_now.upper() == "SAD":
    print("Try talking to someone")
elif mood_right_now.upper() == "ANXIOUS":
    print("Go for box breathing")
else:
    print("Take a break from rouitne")
# Out:
# Welcome to Quick Health Pro-Max Interactive Symptom Checker
# Hello there! Let's check how you're doing today!
# 1.USER PROFILE
# 2.HEALTH INPUTS
# 3.RISK SCORING LOGIC
# 4.HEALTH RISK RESULT
# You are at MODERATE RISK
# 5.PERSONAL ADVICE
# You require health screening
# Take a rouitne checkup to avoid further issues
# 6.MENTAL HEALTH TIP
# Try talking to someone
