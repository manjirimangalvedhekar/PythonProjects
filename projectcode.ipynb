# %% [markdown]
# Personality Test

# %%
import time

# %%
YourName= input("Enter your name: ")
YourAge = int(input("Enter your age: "))
City = input("City you live in: ")
favfood = input("Your fav food: ")
favcolor = input("Your fav color: ")
spiritanimal = input("Enter your spirit animal: ")
hobby = input("One thing you love doing: ")  
agecal = (YourAge * 12) 
secretcode = YourName[0:2].upper() + str(YourAge)[-1] + spiritanimal[0].upper() + favcolor[0].lower()

print("Scanning colors, foods, and animal energies...") 
time.sleep(3)
print("Calculating your personality type using complex non-scientific logic...")
time.sleep(3)
print("Hey Manjiri, here's your fun personality report!")
time.sleep(3)
print(f"Hey,{YourName.title()},you're from {City.title()}, a place of dreams!")
print(f"You love {favfood.title()}, and enjoy {hobby.title()}!")
print(f"You've lived approximately {agecal} already!")
if spiritanimal.upper == "WOLF":
    print("You are Loyal!")
elif spiritanimal.upper == "ELEPHANT":
    print("You have wisdom!")
elif spiritanimal.upper == "OWL":
    print("You have Knowledge!")
elif spiritanimal.upper == "BEAR":
    print("You have Courage!")
elif spiritanimal.upper == "LION":
    print("You have Power!")
else:
    print("You are freedom lover")
print(f"You're secret code is {secretcode}")
# Out:
# Scanning colors, foods, and animal energies...
# Calculating your personality type using complex non-scientific logic...
# Hey Manjiri, here's your fun personality report!
# Hey,Manjiri,you're from Nashik, a place of dreams!
# You love Pani Puri, and enjoy Dance!
# You've lived approximately 384 already!
# You are freedom lover
# You're secret code is MA2Eb
